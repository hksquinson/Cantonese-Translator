# %%
import os
import gc

import pandas as pd
import numpy as np

import torch

from modelscope import snapshot_download

from transformers import AutoTokenizer, PreTrainedTokenizerFast, LlamaTokenizerFast
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

from tqdm import tqdm

from custom_tokenizers import YueTokenizer

# %%
PROJ_DIRECTORY = r'AIST4010-Cantonese-Translator/'
DATA_DIRECTORY = r'AIST4010-Cantonese-Translator-Data/'

yue_path = r'AIST4010-Cantonese-Translator/yue_tokenizer/yue_tokenizer.json'
model_path =r'01ai/Yi-6B-Chat'

# %%
model_dir = snapshot_download('01ai/Yi-6B-Chat', cache_dir='/root/autodl-tmp', revision='master')
print('model found')
yi_tokenizer = AutoTokenizer.from_pretrained(model_path, cache_dir='', use_fast=True, padding_side='right', max_length=512, return_tensors='pt')
print('yi tokenizer loaded')
yue_tokenizer = YueTokenizer.from_pretrained(model_path, cache_dir='', use_fast=True, padding_side='right', max_length=512, return_tensors='pt')
# Out:
# model found
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/trans/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/miniconda3/envs/trans/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
print(len(yi_tokenizer.get_vocab()))
# Out:
# 77969

# %%
print(yue_tokenizer.tokenize("嗌 呃 畀 啲 嘢 噃"))
print(yi_tokenizer.tokenize("嗌 呃 畀 啲 嘢 噃"))
print(yue_tokenizer.tokenize("嗌呃畀啲嘢噃"))
print(yi_tokenizer.tokenize("嗌呃畀啲嘢噃"))

#compare ids 
print(yue_tokenizer.convert_tokens_to_ids(yue_tokenizer.tokenize("嗌 呃 畀 啲 嘢 噃")))
print(yue_tokenizer.convert_tokens_to_ids(yue_tokenizer.tokenize("嗌呃畀啲嘢噃")))
# Out:
# ['嗌', '呃', '畀', '啲', '嘢', '噃']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 print(yue_tokenizer.tokenize("嗌 呃 畀 啲 嘢 噃"))
# ----> 2 print(yi_tokenizer.tokenize("嗌 呃 畀 啲 嘢 噃"))
#       3 print(yue_tokenizer.tokenize("嗌呃畀啲嘢噃"))
#       4 print(yi_tokenizer.tokenize("嗌呃畀啲嘢噃"))
#
# File ~/autodl-tmp/AIST4010-Cantonese-Translator/custom_tokenizers.py:20, in YueTokenizer.tokenize(self, text, **kwargs)
#      17 pre_tokenized_text = " ".join(self.yue_tokenizer.tokenize(text))
#      19 # Tokenize the pre-tokenized text using the yi_tokenizer
# ---> 20 return super()._tokenize(pre_tokenized_text, **kwargs)
#
# AttributeError: 'super' object has no attribute '_tokenize'

# %%
raise Exception
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 raise Exception
#
# Exception:

# %%
yi_tokenizer.save_pretrained('/root/new_tokenizer')
# Out:
# ('/root/new_tokenizer/tokenizer_config.json',
#  '/root/new_tokenizer/special_tokens_map.json',
#  '/root/new_tokenizer/tokenizer.model',
#  '/root/new_tokenizer/added_tokens.json',
#  '/root/new_tokenizer/tokenizer.json')

# %%
print(len(yi_tokenizer.get_vocab()))
print(yi_tokenizer.get_vocab())
# Out:
# 77969
# ...
